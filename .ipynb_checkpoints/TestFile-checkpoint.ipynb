# %% [markdown]
# # This is a Test

# %% [markdown]
# ## If I make a jupyter notebook, will this show up on the website?

# %% [markdown]
# ### What if I plot stuff?

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.linspace(0,3, 100)

plt.plot(X, np.exp(X))
